# %% [markdown]
# # Homework 4 (Only Part)
#
# ## Conceptual
# 1. For an autocoder, what is the purpose of the encoder? What about the decoder?
# 2. What does an autoencoder learn to do when trained on a dataset?
# 3. Why are convolutional autoencoders usually preferred for images over fully connected ones?
# 4. Look up one application of autoencoders which is not anomaly detection and describe how it works.
# 5. What does a variational autoencoder model do that a standard autoencoder does not?
# 6. Why does sampling from the latent space of a trained VAE usually produce plausible outputs, whereas this is not true for standard autoencoders?
# 7. How does a VAE differ conceptually from a GAN in terms of what is being optimized?
# 8. What problem is a GAN trying to solve that traditional generative models approach differently?
# 9. What does it mean for the generator and discriminator to be “adversaries”?
# 10. What does the discriminator learn, and how is that knowledge transferred to the generator?
#
#
# ## Coding
# 1. Using the data set at [this link](https://www.kaggle.com/datasets/emirhanakku/visual-patterns-and-anomalies-synthetic-images?select=dataset.csv), train an autoencoder on the "normal" images and then determine how well it can predict the anomaly images. You may use all of the pattern categories or just a subset. Report the accuracy of your autoencoder after attempts to improve the performace. Summarize the architecture of the best encoder, decoder, and error threshold in a paragraph below the code.
# 2. Train a variational autoencoder on the images in [this dataset](https://www.kaggle.com/datasets/jfgm2018/the-simpsons-dataset-compilation-49-characters). You may use one or more folders within the training data set as desired for your model. Have the trained model produce 10 generated images and display them within your notebook. Summarize the architecture of your VAE and comment on its performance on generating realistic images in a paragraph following the code.
# 3. Perform the same task as Question 2 but with a generative adversarial network instead of a variational autoencoder.
