# %% [markdown]
# # Homework 2 Part 2: Object Detection and Image Segmentation
# ## Conceptual
# Answer the below questions fully and in complete sentences. If you use any resources (including an AI) to answer these questions make sure you include citations.
#
# 1. Research the architecture of YOLO and describe it.
# 2. Research how YOLO was trained to be able to provide not just the bounding box around an object but also to classify the objects. Specifically, what does the y component of the training data look like? Describe your findings in a short paragraph.
# 3. YOLO is not the only option avaliable for object detection. Another common object detection model is SSD. SSD stands for Single Shot MultiBox Detector. Compare and constrast the architecture, training procedure, and performance of these models. Are there tasks that one model is better at then the other?
# 4. U-Net is based on an encoder and a decoder. Research and describe in detail what each component is, what it does, and how it works.
# 5. U-Net is not the only image segmentation software. Research another image segmentation algorithm and compare it to U-Net.
# ## Code
# 1. **Object Detection** Go to Kaggle.com and search "Object Detection Datasets". Find one that is interesting and import it into a Python notebook using the method shown in the lecture notes. Note that since we will not be continuing the training of the YOLO network, the data set just needs to contain the images and not the YOLO training components as the example in the lecture notes does. Note that if your data set does have the appropriate training data then you could attempt to continue the training, even for just a few epochs, but this is not required. Compare the abilties of a pre-trained YOLO model and a pre-trained SSD model to detect the object in your data set. There are several ways to get access to a pre-trained SSD model. Either find one yourself or take a look at [this set of instructions from PyTorch](https://pytorch.org/hub/nvidia_deeplearningexamples_ssd/). Summarize how each model performs across a variety of images in your dataset in a MarkDown paragraph.
# 2. **Image Segmentation** Go to Kaggle.com and search "Image Segmentation Datasets". Find one that is interesting and import it into a Python notebook using the method shown in the lecture notes. Make sure that the dataset has both the images and the masks. If your dataset already has a train-test split then you are good, if not then perform one now. Define a U-Net using a different backbone than ResNet34. You may also change any other parameters you like. Train the U-Net model on the data set and evaluate its performance on the test data. Summarize your findings in a short paragraph. Note 1: U-Net was originally developed for biological applications and if you want to stay true to these roots there are a few interesting data sets on Kaggle involving tumor detection that include masks. Note 2: If you are having trouble getting the images and masks imported in a usable format, see if there are any posted notebooks on Kaggle using the data set and model your import code after them.
