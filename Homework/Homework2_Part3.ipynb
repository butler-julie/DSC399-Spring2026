# %% [markdown]
# # Transformers for Image Processing (Vision Transformers)
#
# ## Conceptual
# Answer the following questions in complete sentences. Make sure you provide a citation (at least a URL) to any resources which are not in the class notes.
#
# 1. What is the pre-processing method for vision transformers compared to NLP transformers? Speficially, what are the equivalents, if any, for chunking, tokenization, position embedding, and embedding (vectorization)?
# 2. What is the architecture of a vision transformer after the pre-processing? Does it differ from an NLP transformer?
# 3. What are the benefits of using a vision transformer over a convolutional neural network for image analysis? What are the drawbacks?
# 4. [PyTorch has several built-in vision transformer models](https://docs.pytorch.org/vision/main/models/vision_transformer.html). Choose one and describe how it works, how the images need to be formatted, and what pre-processing needs to be performed (or if the model does the pre-processing). If these models are pre-trained, what are they trained on and what task(s) are they trained to do?
#
# ## Code
# Choose a pre-trained vision transformer model from the PyTorch documentation and train it on the CIFAR-10 dataset (hint you can use the same code we used for pre-trained CNNs, just replace the model name). Try various parameters to see how this affects the accuracy of the predictions. Compare your best accuracy obtained in this homework to the best accuracy you found in part 1 using pre-trained CNNs.
#
# ## Suggested Resources
# * [An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale](https://arxiv.org/abs/2010.11929)
# * [Vision Transformer: What It Is & How It Works](https://www.v7labs.com/blog/vision-transformer-guide)
# * [Vision Transformer and MLP-Mixer Architectures](https://github.com/google-research/vision_transformer?tab=readme-ov-file)
#     * Note: the implemenations are tensorflow but the information is good.
# * [How to train your ViT? Data, Augmentation, and Regularization in Vision Transformers](https://arxiv.org/abs/2106.10270)
# * [When Vision Transformers Outperform ResNets without Pre-training or Strong Data Augmentations](http://arxiv.org/abs/2106.01548)
# * [Building a Vision Transformer Model From Scratch](https://medium.com/correll-lab/building-a-vision-transformer-model-from-scratch-a3054f707cc6)
# * [Vision Transformer (ViT) (Hugging Face)](https://huggingface.co/docs/transformers/en/model_doc/vit)
#     * We will use PyTorch for a pre-trained vision transformer implemenation, but there are also options avaliable from hugging face.
# * [CNN vs. Vision Transformer: A Practitioner's Guide to Selecting the Right Model](https://tobiasvanderwerff.com/2024/05/15/cnn-vs-vit.html)
