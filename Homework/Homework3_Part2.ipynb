# %% [markdown]
# # Homework 3 Part 2: Reinforcement Learning
#
# ## Conceptual
# 1. What does the Q-value represent in Q-learning?
# 2. Explain why Q-learning is model-free and off-policy.
# 3. What is the purpose of the discount factor, $\gamma$?
# 4. Why do we implement $\epsilon$-greedy exploration and $\epsilon$ decay?
# 5. What is the key limitation of Q‑learning that motivates Deep Q‑Learning?
# 6. What is the key limitation of tabular Q‑learning that motivates Deep Q‑Learning?
# 7. What problem does experience replay address in DQN?
# 8. What is the purpose of a target network in DQN?
# 9. What role does ε‑greedy exploration play in DQN, even though the Q‑function is learned with a neural network?
#
# ## Coding
#
# ### Environment
# * Create a two-dimensional square GridWorld where free cells are represented as ., walls are represented as #, the start state is represented as S, and the goal as G. The size of the grid must be given as a parameter to the initializer and the grid must scale to any size.
# * Your GriWorld must have the ability to reset the state and to take a step based on an action. The actions that can be taken are up, down, left, and right one one cell steps. T
# * he agent is not allowed to move through the walls are leave the grid.
# * The reward for taking a step is -1 and the reward for reaching the goal is 20 and is terminal.
# * You must also have a way to visualize the starting state of your GridWorld
#
# ### Q-Learning
# * Implement a Q-learning algorithm in your GridWorld. It must use a $\epsilon$-greedy exploration with an $\epsilon$ decay schedule.
# *  The algorithm must be able to compute the learning curve and visualize the final rollout.
# * Try different values of $\alpha$, $\gamma$, $\epsilon$, and $\epsilon$ decay schedules, as well as different starting points, goal points, and grids. Summarize your results in a couple paragraphs.
#
# ## Deep Q-Learning
# * Implement a Deep Q-Learning algorithm in your GridWorld. It must have an experience relay buffer, a target network, and $\epsilon$-greedy exploration.
# * Architecture: Choose one of the following input encodings: one-hot state, (row, col), or Grid image. The output must the the Q-values for the four possible actions.
# *  The algorithm must be able to compute the learning curve and visualize the final rollout.
# * Try different values of $\alpha$, $\gamma$, $\epsilon$, and $\epsilon$ decay schedules, as well as different starting points, goal points, and grids. Summarize your results in a couple paragraphs.
#
# ### Comparison
# * Finally, write a paragraph comparing the learning speed and final performance of the two algorithms as the size of the grid increases.
