# %% [markdown]
# # Homework 2 Part 4: Diffusion Models
#
# ## Conceptual
# 1. The base diffusion model is the DDPM model discussed in the lecture notes. Research this model and discuss in a couple paragraphs how it works.
# 2. In the code example we used DDIM in order to generate an image with less time steps. Research this model and describe how it can be faster than DPMM. Report your results in a couple paragraphs.
# 3. A popular image generator is Stable Diffusion. Research the architecture of this model and describe the format of the U-Net and what type of diffusion is used in its training.
# 4. What are you thinking of doing for your final project? Describe it in a couple paragraphs.
#
# ## Code
# Choose a pre-trained diffusion model from Hugging Face, different from the ones shown in class. This model can do text to image generation or anything else avaliable. Be careful with the number of parameters, just like with LLMs (i.e. stick to 1-2 billion parameters or less unless you have a GPU).
# * Explain the architecture of your model and the type of diffusion used (DDPM, DIMM, other).
# * Implement and test the pre-trained model. Summarize your experiences with the model in a couple paragraphs. How did it do in recreating the images it was trained on? How realistic (within the scope of the training data) are the images?
